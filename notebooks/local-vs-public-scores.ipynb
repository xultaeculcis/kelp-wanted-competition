# %%
import pandas as pd
import seaborn as sns

sns.scatterplot(pd.read_csv("../data/submissions/submission-log.csv"), x="local-score", y="public-score")
# Out:
# <Axes: xlabel='local-score', ylabel='public-score'>

# %%
sns.scatterplot(pd.read_csv("../data/submissions/submission-log.csv"), x="cv-split", y="public-score")
# Out:
# <Axes: xlabel='cv-split', ylabel='public-score'>
